# %% [markdown]
# # **ANALISIS EXPLORATORIO INICIAL**
#
# - ALUMNO: DIEGO CESAR LARICO CRUZ - 20212679A
#
# **NOTA**: Cargar el csv dentro de los archivos del colab para ejecutar el EDA sin problemas

# %%
import pandas as pd

# Cargar el dataset
df = pd.read_csv('Datos_abiertos_cepre_2024_1_2025_1.csv')

# %%
df.head()
# Out:
#                                               IDHASH  \
# 0  BE11517F469351A6FA152F8AD70F9707812804B0112D18...
# 1  5519D203EC72BC2D14DEB410AFEB66E22C5E135A9232AB...
# 2  FB5D70645AC934046646CDD8BD162714E324A8E444E5EE...
# 3  063276C4ED0A1A0115AC54FACFD30F3DA43DD686E311B7...
# 4  49275FD4C1059A9D9EA42C7C8FA4C86F1357E6BF428779...
#
#                     COLEGIO COLEGIO_DEPA COLEGIO_PROV            COLEGIO_DIST  \
# 0          cristian huygens         LIMA         LIMA  SAN JUAN DE LURIGANCHO
# 1    COLEGIO EL COMERCIO 32         PUNO    SAN ROMAN                 JULIACA
# 2  I E Manuel Scorza Torres         LIMA         LIMA           INDEPENDENCIA
# 3            RICARDO BENTIN         LIMA         LIMA                   RIMAC
# 4                    Trilce         LIMA         LIMA             JESUS MARIA
#
#   COLEGIO_PAIS  COLEGIO_ANIO_EGRESO         ESPECIALIDAD  ANIO_POSTULA  \
# 0         PERU                 2021     SIN ESPECIALIDAD          2024
# ...

# %%
#dimensiones del dataframe
df.shape
# Out:
# (8470, 23)

# %%
# Verificamos las variables
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8470 entries, 0 to 8469
# Data columns (total 23 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   IDHASH               8470 non-null   object
#  1   COLEGIO              8470 non-null   object
#  2   COLEGIO_DEPA         8470 non-null   object
#  3   COLEGIO_PROV         8470 non-null   object
#  4   COLEGIO_DIST         8470 non-null   object
#  5   COLEGIO_PAIS         8470 non-null   object
#  6   COLEGIO_ANIO_EGRESO  8470 non-null   int64
#  7   ESPECIALIDAD         8470 non-null   object
#  8   ANIO_POSTULA         8470 non-null   int64
#  9   CICLO_POSTULA        8470 non-null   int64
#  10  DOMICILIO_DEPA       8470 non-null   object
#  11  DOMICILIO_PROV       8470 non-null   object
#  12  DOMICILIO_DIST       8470 non-null   object
#  13  ANIO_NACIMIENTO      8470 non-null   int64
#  14  NACIMIENTO_PAIS      8470 non-null   object
# ...

# %% [markdown]
# Conclusiones hasta este punto:
# - No hay valores nulos
# - Se debe renombrar las variables

# %% [markdown]
# Ahora evaluamos las variables

# %%
#variables categoricas

print(df.describe(include=['O']))
# Out:
#                                                    IDHASH        COLEGIO  \
# count                                                8470           8470
# unique                                               5808           4614
# top     AE1C391A973804E2AAE891DAD46D7B56A784223D2285F1...  Saco Oliveros
# freq                                                    3            312
#
#        COLEGIO_DEPA COLEGIO_PROV COLEGIO_DIST COLEGIO_PAIS      ESPECIALIDAD  \
# count          8470         8470         8470         8470              8470
# unique           25          141          364            1                32
# top            LIMA         LIMA         LIMA         PERU  SIN ESPECIALIDAD
# freq           6391         6114          837         8470              6902
#
#        DOMICILIO_DEPA DOMICILIO_PROV DOMICILIO_DIST NACIMIENTO_PAIS  \
# count            8470           8470           8470            8470
# unique             22             98            238              12
# ...

# %% [markdown]
# - FECHA_CORTE no es significativo
# - COLEGIO_PAIS no es significativo, todos son de PERU

# %%
cols = ['CICLO_POSTULA', 'ANIO_POSTULA', 'MODO_INGRESO', 'INGRESO', 'SEXO']

for col in cols:
    print(f"\n Valores únicos: {col}")
    print(df[col].unique())
# Out:
#  Valores únicos: CICLO_POSTULA
# [1 2]
#
#  Valores únicos: ANIO_POSTULA
# [2024 2025]
#
#  Valores únicos: MODO_INGRESO
# ['SIN INGRESO' 'ORDINARIO' 'DIRECTO']
#
#  Valores únicos: INGRESO
# ['NO' 'SI']
#
#  Valores únicos: SEXO
# ['MASCULINO' 'FEMENINO']

# %%
# Variables numericas
print(df.describe())
# Out:
#        COLEGIO_ANIO_EGRESO  ANIO_POSTULA  CICLO_POSTULA  ANIO_NACIMIENTO  \
# count          8470.000000   8470.000000    8470.000000      8470.000000
# mean           2021.537190   2024.316057       1.368359      2004.839315
# std               1.897783      0.464963       0.482388        21.804145
# min            1997.000000   2024.000000       1.000000         6.000000
# 25%            2021.000000   2024.000000       1.000000      2004.000000
# 50%            2022.000000   2024.000000       1.000000      2005.000000
# 75%            2023.000000   2025.000000       2.000000      2006.000000
# max            2024.000000   2025.000000       2.000000      2009.000000
#
#        CALIF_FINAL  FECHA_CORTE
# count  8470.000000       8470.0
# mean      7.412488   20250630.0
# std       4.141927          0.0
# min       0.000000   20250630.0
# 25%       3.960250   20250630.0
# 50%       7.524000   20250630.0
# 75%      10.832750   20250630.0
# max      17.343000   20250630.0

# %%
# Muestra los valores únicos de la columna 'MODO_INGRESO'
df['MODO_INGRESO'].unique()
# Out:
# array(['SIN INGRESO', 'ORDINARIO', 'DIRECTO'], dtype=object)

# %%
# Muestra los valores únicos de la columna 'CICLO_POSTULA'
df['CICLO_POSTULA'].unique()
# Out:
# array([1, 2])

# %%
df['FECHA_CORTE'].unique()
# Out:
# array([20250630])

# %%
df['ANIO_POSTULA'].unique()
# Out:
# array([2024, 2025])

# %%
pd.crosstab(df['CICLO_POSTULA'], df['ANIO_POSTULA'])
# Out:
# ANIO_POSTULA   2024  2025
# CICLO_POSTULA
# 1              2673  2677
# 2              3120     0

# %% [markdown]
# Tenemos los siguientes resultados
# - Postulantes 24-1: 2673
# - Postulantes 24-2: 3120
# - Postulantes 25-1: 2677
